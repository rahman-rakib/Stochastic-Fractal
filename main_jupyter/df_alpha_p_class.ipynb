# %%
import random, numpy as np, pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

# %%
# %run ../../stochastic_fractal_m.py

# %%
alphap = 2
probp = 0.75

# %%
ensemble_size = 500*1
time_iteration = 1000*100
min_iteration = 1000*10

# number_of_points = 21

iteration_step = 5000

# %% [markdown]
# ## Directories

# %%
dir_data = "../../data/alpha{}/".format(alphap)
dir_fig  ="../../figures/alpha{}/".format(alphap)


## While testing
dir_data = "../../data/temp/alpha{}/".format(alphap)
dir_fig  ="../../figures/temp/alpha{}/".format(alphap)

# create directory if it does not exists
for dir_name in [dir_data, dir_fig]:
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
        print("directory ", dir_name, " is created")
    else:
        print("directory ", dir_name, " exists")
    pass

### Filename
filename = "fractal_dim_alpha_{}_p_{}".format(alphap, int(probp*100))
out_data_filename = dir_data +filename
print(out_data_filename)
# Out:
# directory  ../../data/temp/alpha2/  exists
# directory  ../../figures/temp/alpha2/  exists
# ../../data/temp/alpha2/fractal_dim_alpha_2_p_75

# %% [markdown]
# ## Simulation

# %%
sf_numberlength = NumberLength(alpha=alphap, probability=probp)
sf_numberlength.log(True)
# Out:
# kwargs  {'alpha': 2, 'probability': 0.75}

# %%
data = sf_numberlength.run_ensemble(ensemble_size, time_iteration, min_iteration, iteration_step)
# Out:
# realization  5  . Time spent  0.6881058216094971  sec
# realization  10  . Time spent  0.7006814479827881  sec
# realization  15  . Time spent  0.6149511337280273  sec
# realization  20  . Time spent  0.5908279418945312  sec
# realization  25  . Time spent  0.71199631690979  sec
# realization  30  . Time spent  0.7233133316040039  sec
# realization  35  . Time spent  0.6424169540405273  sec
# realization  40  . Time spent  0.6667888164520264  sec
# realization  45  . Time spent  0.5864157676696777  sec
# realization  50  . Time spent  0.6447803974151611  sec
# realization  55  . Time spent  0.569324254989624  sec
# realization  60  . Time spent  0.6820828914642334  sec
# realization  65  . Time spent  0.6872384548187256  sec
# realization  70  . Time spent  0.9070377349853516  sec
# realization  75  . Time spent  0.6429474353790283  sec
# realization  80  . Time spent  0.7119119167327881  sec
# realization  85  . Time spent  0.9142167568206787  sec
# realization  90  . Time spent  0.8135762214660645  sec
# realization  95  . Time spent  0.9022772312164307  sec
# realization  100  . Time spent  0.8254799842834473  sec
# realization  105  . Time spent  0.8012514114379883  sec
# realization  110  . Time spent  0.9351723194122314  sec
# realization  115  . Time spent  0.7653489112854004  sec
# realization  120  . Time spent  0.7173974514007568  sec
# realization  125  . Time spent  0.6046741008758545  sec
# realization  130  . Time spent  0.6879527568817139  sec
# realization  135  . Time spent  0.5776529312133789  sec
# realization  140  . Time spent  0.6268424987792969  sec
# realization  145  . Time spent  0.7215163707733154  sec
# realization  150  . Time spent  0.6024651527404785  sec
# realization  155  . Time spent  0.6520397663116455  sec
# realization  160  . Time spent  0.5646629333496094  sec
# realization  165  . Time spent  0.5497345924377441  sec
# realization  170  . Time spent  0.5710842609405518  sec
# realization  175  . Time spent  0.5754597187042236  sec
# realization  180  . Time spent  0.5556650161743164  sec
# realization  185  . Time spent  0.6592633724212646  sec
# realization  190  . Time spent  0.6854989528656006  sec
# realization  195  . Time spent  0.6973419189453125  sec
# realization  200  . Time spent  0.5960509777069092  sec
# realization  205  . Time spent  0.5933525562286377  sec
# realization  210  . Time spent  0.5511090755462646  sec
# realization  215  . Time spent  0.6090037822723389  sec
# realization  220  . Time spent  0.7439675331115723  sec
# realization  225  . Time spent  0.6672439575195312  sec
# realization  230  . Time spent  0.5869052410125732  sec
# realization  235  . Time spent  0.6113722324371338  sec
# realization  240  . Time spent  0.5964128971099854  sec
# realization  245  . Time spent  0.5581824779510498  sec
# realization  250  . Time spent  0.670769214630127  sec
# realization  255  . Time spent  0.660759449005127  sec
# realization  260  . Time spent  0.6328709125518799  sec
# realization  265  . Time spent  0.5997755527496338  sec
# realization  270  . Time spent  0.5850009918212891  sec
# realization  275  . Time spent  0.6695096492767334  sec
# realization  280  . Time spent  0.5996899604797363  sec
# realization  285  . Time spent  0.5654542446136475  sec
# realization  290  . Time spent  0.5793836116790771  sec
# realization  295  . Time spent  0.5376780033111572  sec
# realization  300  . Time spent  0.5773823261260986  sec
# realization  305  . Time spent  0.6348700523376465  sec
# realization  310  . Time spent  0.5551750659942627  sec
# realization  315  . Time spent  0.5381886959075928  sec
# realization  320  . Time spent  0.5437743663787842  sec
# realization  325  . Time spent  0.6953141689300537  sec
# realization  330  . Time spent  0.661475658416748  sec
# realization  335  . Time spent  0.6881778240203857  sec
# realization  340  . Time spent  0.8260433673858643  sec
# realization  345  . Time spent  0.6134092807769775  sec
# realization  350  . Time spent  0.5877106189727783  sec
# realization  355  . Time spent  0.5665946006774902  sec
# realization  360  . Time spent  0.5607709884643555  sec
# realization  365  . Time spent  0.594414234161377  sec
# realization  370  . Time spent  0.5680387020111084  sec
# realization  375  . Time spent  0.5846714973449707  sec
# realization  380  . Time spent  0.6704840660095215  sec
# realization  385  . Time spent  0.676844596862793  sec
# realization  390  . Time spent  0.6495490074157715  sec
# realization  395  . Time spent  0.7018358707427979  sec
# realization  400  . Time spent  0.5892753601074219  sec
# realization  405  . Time spent  0.6082131862640381  sec
# realization  410  . Time spent  0.6336469650268555  sec
# realization  415  . Time spent  0.8141357898712158  sec
# realization  420  . Time spent  0.8184654712677002  sec
# realization  425  . Time spent  0.9233686923980713  sec
# realization  430  . Time spent  0.7301030158996582  sec
# realization  435  . Time spent  0.7917759418487549  sec
# realization  440  . Time spent  0.8019609451293945  sec
# realization  445  . Time spent  0.6854820251464844  sec
# realization  450  . Time spent  0.7364649772644043  sec
# realization  455  . Time spent  0.8017945289611816  sec
# realization  460  . Time spent  0.6584489345550537  sec
# realization  465  . Time spent  0.6659858226776123  sec
# realization  470  . Time spent  0.7268252372741699  sec
# realization  475  . Time spent  0.6201038360595703  sec
# realization  480  . Time spent  0.6079580783843994  sec
# realization  485  . Time spent  0.6944262981414795  sec
# realization  490  . Time spent  0.6046063899993896  sec
# realization  495  . Time spent  0.6558434963226318  sec
# realization  500  . Time spent  0.6950821876525879  sec
# Total time spent  66.38633155822754  sec

# %%
fig, axes = plt.subplots(1,1,figsize = (5,3.5),dpi = 200)
N1_average, M1_average = data.T
N1_log = np.log(N1_average)
minus_delta1_log = N1_log - np.log(M1_average)
slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
print("estimated df(alpha, p)= ", slope)
plt.plot(minus_delta1_log, N1_log, "o")
plt.xlabel(r"$-\ln\,\delta$")
plt.ylabel(r"$\ln\,N$")
axes.set_position([0.15,0.15,0.75,0.75])
# Out:
# estimated df(alpha, p)=  0.7768672286628188

# %%
print("estimated   df = ", slope)
ana_soln = AnalyticSoln()
print("Theoritical df =", ana_soln.find_df(alphap, probp))
# Out:
# estimated   df =  0.7768672286628188
# Theoritical df = 0.778719

# %%
N1_average
# Out:
# array([17.158, 19.064, 20.654, 21.866, 22.852, 23.796, 24.634, 25.396,
#        26.108, 26.746, 27.322, 27.906, 28.448, 28.926, 29.408, 29.906,
#        30.4  , 30.806, 31.194])

# %%
M1_average
# Out:
# array([0.44934026, 0.43572042, 0.42617483, 0.41919139, 0.4135607 ,
#        0.40941224, 0.4053296 , 0.40192624, 0.39863899, 0.39597685,
#        0.39304295, 0.39126082, 0.38866302, 0.38672961, 0.38491913,
#        0.38295366, 0.38120247, 0.37967176, 0.37835596])

# %% [markdown]
# ## Write data to file

# %%
header = dict()
header['alpha'] = alphap
header['probability'] = probp
header['ensemble_size']=ensemble_size
header['total_time_iteraion']=time_iteration
header['min_time_iteraion']=min_iteration
header['cols'] = ["t", "N", "M"]

time_col = np.arange(min_iteration, time_iteration+1, iteration_step)

header_str = json.dumps(header)
print(header_str)
print(out_data_filename)
# np.savetxt(out_data_filename, np.c_[time_col, N1_average, M1_average], header=header_str)
# Out:
# {"alpha": 2, "probability": 0.75, "ensemble_size": 500, "total_time_iteraion": 100000, "min_time_iteraion": 10000, "cols": ["t", "N", "M"]}
# ../../data/temp/alpha2/fractal_dim_alpha_2_p_75

# %% [markdown]
# ### plot $-\ln \delta$ vs $\ln t$

# %%
def convert_to_plot(N1_average, M1_average):
    N1_log = np.log(N1_average)
    minus_delta1_log = N1_log - np.log(M1_average)
    slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
    return minus_delta1_log, N1_log, slope, intercept

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 3.5), dpi=300)
colors = ['tab:blue', 'tab:orange', 'tab:green']

i = 0

tt = np.arange(min_iteration, time_iteration+1, iteration_step)

t, N, M =tt, N1_average, M1_average
y, yyy, slope, intercept = convert_to_plot(N, M)
log_t = np.log(t)

regress = stats.linregress(log_t, y)
plt.plot(log_t, y, 'o', color=colors[i], markersize=1.5)
yyyyy = log_t*regress[0] + regress[1]
plt.plot(log_t, yyyyy, label=r"$p={:.2f}: slope={:.5f}$".format(probp, regress[0]),  color=colors[i], linewidth=1)
i += 1

# plt.legend(loc='best', bbox_to_anchor=(0.5, 0.05, 0.5, 0.5))
plt.legend(loc=2)
plt.ylabel(r"$-\ln \delta$")
plt.xlabel(r"$\ln t$")
# plt.ylim([0.5, 3])
ax.set_position([0.15, 0.15, 0.8, 0.8])
# print(fig_filename)
# plt.savefig(fig_filename
