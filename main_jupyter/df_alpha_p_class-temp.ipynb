# %% [markdown]
# # Temp

# %%
import random, numpy as np, pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

# %%
# %run ../../stochastic_fractal_m.py

# %%
alphap = 3
probp = 0.75

# %%
ensemble_size = 1000*10
time_iteration = 1000*100
min_iteration = 1000*10

# number_of_points = 21

iteration_step = 1000*5

# %% [markdown]
# ## Directories

# %%
dir_data = "../../data/alpha{}/".format(alphap)
dir_fig  ="../../figures/alpha{}/".format(alphap)


## While testing
dir_data = "../../data/temp/alpha{}/".format(alphap)
dir_fig  ="../../figures/temp/alpha{}/".format(alphap)

# create directory if it does not exists
for dir_name in [dir_data, dir_fig]:
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
        print("directory ", dir_name, " is created")
    else:
        print("directory ", dir_name, " exists")
    pass

### Filename
filename = "fractal_dim_alpha_{}_p_{}".format(alphap, int(probp*100))
out_data_filename = dir_data +filename
print(out_data_filename)
# Out:
# directory  ../../data/temp/alpha3/  exists
# directory  ../../figures/temp/alpha3/  exists
# ../../data/temp/alpha3/fractal_dim_alpha_3_p_75

# %%
sf_numberlength = NumberLengthTemp(alpha=alphap, probability=probp)
sf_numberlength.log(True)
# Out:
# kwargs  {'alpha': 3, 'probability': 0.75}

# %%
sf_numberlength.run(time_iteration, min_iteration, iteration_step)
# Out:
# array([[ 9.        ,  0.92525783],
#        [10.        ,  0.92525783],
#        [12.        ,  0.92525783],
#        [13.        ,  0.92525783],
#        [13.        ,  0.84439731],
#        [13.        ,  0.84439731],
#        [14.        ,  0.84439731],
#        [14.        ,  0.84439731],
#        [14.        ,  0.84439731],
#        [14.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [15.        ,  0.84439731],
#        [16.        ,  0.84439731],
#        [16.        ,  0.84439731]])

# %%
data = sf_numberlength.run_ensemble(ensemble_size, time_iteration, min_iteration, iteration_step)
# Out:
# realization  100  . Time spent  10.01322078704834  sec
# realization  200  . Time spent  9.534574031829834  sec
# realization  300  . Time spent  9.720960855484009  sec
# realization  400  . Time spent  9.643064022064209  sec
# realization  500  . Time spent  9.747058629989624  sec
# realization  600  . Time spent  9.491653442382812  sec
# realization  700  . Time spent  9.661409854888916  sec
# realization  800  . Time spent  9.668137550354004  sec
# realization  900  . Time spent  9.610830068588257  sec
# realization  1000  . Time spent  9.599377393722534  sec
# realization  1100  . Time spent  9.62684679031372  sec
# realization  1200  . Time spent  9.619350910186768  sec
# realization  1300  . Time spent  9.601986169815063  sec
# realization  1400  . Time spent  9.565137386322021  sec
# realization  1500  . Time spent  9.587846040725708  sec
# realization  1600  . Time spent  9.655912399291992  sec
# realization  1700  . Time spent  9.430147886276245  sec
# realization  1800  . Time spent  9.50912356376648  sec
# realization  1900  . Time spent  9.616652965545654  sec
# realization  2000  . Time spent  9.64573049545288  sec
# realization  2100  . Time spent  9.61497950553894  sec
# realization  2200  . Time spent  9.550588607788086  sec
# realization  2300  . Time spent  9.664067506790161  sec
# realization  2400  . Time spent  9.57095217704773  sec
# realization  2500  . Time spent  9.63882851600647  sec
# realization  2600  . Time spent  9.650770664215088  sec
# realization  2700  . Time spent  9.60565733909607  sec
# realization  2800  . Time spent  9.591246128082275  sec
# realization  2900  . Time spent  9.629477977752686  sec
# realization  3000  . Time spent  9.608938217163086  sec
# realization  3100  . Time spent  9.69251799583435  sec
# realization  3200  . Time spent  9.706169366836548  sec
# realization  3300  . Time spent  10.220040321350098  sec
# realization  3400  . Time spent  9.608811140060425  sec
# realization  3500  . Time spent  9.56879711151123  sec
# realization  3600  . Time spent  9.50980019569397  sec
# realization  3700  . Time spent  9.60937786102295  sec
# realization  3800  . Time spent  9.516630411148071  sec
# realization  3900  . Time spent  9.64739727973938  sec
# realization  4000  . Time spent  9.52090072631836  sec
# realization  4100  . Time spent  9.59842824935913  sec
# realization  4200  . Time spent  9.555238723754883  sec
# realization  4300  . Time spent  9.71618103981018  sec
# realization  4400  . Time spent  9.904236316680908  sec
# realization  4500  . Time spent  10.278584241867065  sec
# realization  4600  . Time spent  9.784707307815552  sec
# realization  4700  . Time spent  9.724786043167114  sec
# realization  4800  . Time spent  9.870172262191772  sec
# realization  4900  . Time spent  9.800921440124512  sec
# realization  5000  . Time spent  9.974133014678955  sec
# realization  5100  . Time spent  9.87908124923706  sec
# realization  5200  . Time spent  10.13020658493042  sec
# realization  5300  . Time spent  9.675121784210205  sec
# realization  5400  . Time spent  9.757538080215454  sec
# realization  5500  . Time spent  9.788023471832275  sec
# realization  5600  . Time spent  9.591978788375854  sec
# realization  5700  . Time spent  9.821931600570679  sec
# realization  5800  . Time spent  9.711153745651245  sec
# realization  5900  . Time spent  9.690306901931763  sec
# realization  6000  . Time spent  9.625607013702393  sec
# realization  6100  . Time spent  9.608594179153442  sec
# realization  6200  . Time spent  9.63291335105896  sec
# realization  6300  . Time spent  9.624650001525879  sec
# realization  6400  . Time spent  9.694830894470215  sec
# realization  6500  . Time spent  9.736755132675171  sec
# realization  6600  . Time spent  9.3892183303833  sec
# realization  6700  . Time spent  9.994262933731079  sec
# realization  6800  . Time spent  9.66322112083435  sec
# realization  6900  . Time spent  9.62394905090332  sec
# realization  7000  . Time spent  9.66785454750061  sec
# realization  7100  . Time spent  9.63104510307312  sec
# realization  7200  . Time spent  9.653983116149902  sec
# realization  7300  . Time spent  9.558454513549805  sec
# realization  7400  . Time spent  9.58301830291748  sec
# realization  7500  . Time spent  9.59548568725586  sec
# realization  7600  . Time spent  9.64683198928833  sec
# realization  7700  . Time spent  9.606733560562134  sec
# realization  7800  . Time spent  9.625559091567993  sec
# realization  7900  . Time spent  9.621601343154907  sec
# realization  8000  . Time spent  9.676487445831299  sec
# realization  8100  . Time spent  9.685517311096191  sec
# realization  8200  . Time spent  9.69442629814148  sec
# realization  8300  . Time spent  9.693516254425049  sec
# realization  8400  . Time spent  9.659698247909546  sec
# realization  8500  . Time spent  9.67536997795105  sec
# realization  8600  . Time spent  9.637861490249634  sec
# realization  8700  . Time spent  9.588982105255127  sec
# realization  8800  . Time spent  9.645389318466187  sec
# realization  8900  . Time spent  9.600679636001587  sec
# realization  9000  . Time spent  9.544235706329346  sec
# realization  9100  . Time spent  9.641046524047852  sec
# realization  9200  . Time spent  9.56852674484253  sec
# realization  9300  . Time spent  9.60223913192749  sec
# realization  9400  . Time spent  9.688879489898682  sec
# realization  9500  . Time spent  9.725017547607422  sec
# realization  9600  . Time spent  9.652775287628174  sec
# realization  9700  . Time spent  9.569299697875977  sec
# realization  9800  . Time spent  9.665058374404907  sec
# realization  9900  . Time spent  9.623884201049805  sec
# realization  10000  . Time spent  9.655519962310791  sec
# Total time spent  966.8440239429474  sec

# %%
fig, axes = plt.subplots(1,1,figsize = (5,3.5),dpi = 200)
N1_average, M1_average = data.T
N1_log = np.log(N1_average)
minus_delta1_log = N1_log - np.log(M1_average)
slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
print("estimated df(alpha, p)= ", slope)
plt.plot(minus_delta1_log, N1_log, "o")
plt.xlabel(r"$-\ln\,\delta$")
plt.ylabel(r"$\ln\,N$")
axes.set_position([0.15,0.15,0.75,0.75])
# Out:
# estimated df(alpha, p)=  0.7900149636258732

# %%
print("estimated   df = ", slope)
ana_soln = AnalyticSoln()
print("Theoritical df =", ana_soln.find_df(alphap, probp))
# Out:
# estimated   df =  0.7900149636258732
# Theoritical df = 0.788345

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 3.5), dpi=300)
colors = ['tab:blue', 'tab:orange', 'tab:green']

i = 0

t = np.arange(min_iteration, time_iteration+1, iteration_step)

log_t = np.log(t)

regress = stats.linregress(log_t, minus_delta1_log)
plt.plot(log_t, minus_delta1_log, 'o', color=colors[i], markersize=1.5)
yyyyy = log_t*regress[0] + regress[1]
plt.plot(log_t, yyyyy, label=r"$p={:.2f}: slope={:.5f}$".format(probp, regress[0]),  color=colors[i], linewidth=1)
i += 1

# plt.legend(loc='best', bbox_to_anchor=(0.5, 0.05, 0.5, 0.5))
plt.legend(loc=2)
plt.ylabel(r"$-\ln \delta$")
plt.xlabel(r"$\ln t$")
# plt.ylim([0.5, 3])
ax.set_position([0.15, 0.15, 0.8, 0.8])
# print(fig_filename)
# plt.savefig(fig_filename
print(regress[0])
# Out:
# 0.20138325344575836

# %%
N1_average.shape

# %%
N1_average

# %%
M1_average
# Out:
# array([0.38803979, 0.37653253, 0.36879224, 0.3628475 , 0.35803695,
#        0.35398417, 0.35042595, 0.34734646, 0.34457634, 0.34219887,
#        0.33998225, 0.33807849, 0.336212  , 0.33442269, 0.33279203,
#        0.33130658, 0.32991805, 0.32864114, 0.32742283])

# %% [markdown]
# ### Write data to file

# %%
header = dict()
header['alpha'] = alphap
header['probability'] = probp
header['ensemble_size']=ensemble_size
header['total_time_iteraion']=time_iteration
header['min_time_iteraion']=min_iteration
header['cols'] = ["t", "N", "M"]

time_col = np.arange(min_iteration, time_iteration+1, iteration_step)

header_str = json.dumps(header)
print(header_str)
print(out_data_filename)
# np.savetxt(out_data_filename, np.c_[time_col, N1_average, M1_average], header=header_str)
# Out:
# {"alpha": 2, "probability": 0.75, "ensemble_size": 10000, "total_time_iteraion": 1000000, "min_time_iteraion": 100000, "cols": ["t", "N", "M"]}
# ../../data/temp/alpha2/fractal_dim_alpha_2_p_75

# %% [markdown]
# ### plot $-\ln \delta$ vs $\ln t$

# %%
def convert_to_plot(N1_average, M1_average):
    N1_log = np.log(N1_average)
    minus_delta1_log = N1_log - np.log(M1_average)
    slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
    return minus_delta1_log, N1_log, slope, intercept

# %%
tt.shape
# Out:
# (19,)
