# %%
import random, numpy as np, pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %run ../../stochastic_fractal_m.py

# %%
alphap = 2
probp = 0.75

# %%
ensemble_size = 100*1
time_iteration = 1000*1000
mid_iteration = 1000*50
number_of_points = 20

# %% [markdown]
# ## Directories

# %%
sf_numberlength = NumberLength(alpha=alphap, probability=probp)
sf_numberlength.log(True)
# Out:
# kwargs  {'alpha': 2, 'probability': 0.75}

# %%
data = sf_numberlength.run_ensemble(ensemble_size, time_iteration, mid_iteration, number_of_points)
# Out:
# realization  1  . Time spent  1.7172050476074219  sec
# realization  2  . Time spent  1.1201252937316895  sec
# realization  3  . Time spent  1.1483194828033447  sec
# realization  4  . Time spent  1.0815601348876953  sec
# realization  5  . Time spent  1.1665852069854736  sec
# realization  6  . Time spent  1.1448180675506592  sec
# realization  7  . Time spent  1.0855779647827148  sec
# realization  8  . Time spent  1.1077136993408203  sec
# realization  9  . Time spent  1.1866369247436523  sec
# realization  10  . Time spent  1.8121757507324219  sec
# realization  11  . Time spent  1.3749332427978516  sec
# realization  12  . Time spent  1.2495911121368408  sec
# realization  13  . Time spent  1.2552919387817383  sec
# realization  14  . Time spent  1.1258869171142578  sec
# realization  15  . Time spent  1.3360671997070312  sec
# realization  16  . Time spent  1.2458109855651855  sec
# realization  17  . Time spent  1.0900847911834717  sec
# realization  18  . Time spent  2.196416139602661  sec
# realization  19  . Time spent  1.2443864345550537  sec
# realization  20  . Time spent  1.2374217510223389  sec
# realization  21  . Time spent  1.0438330173492432  sec
# realization  22  . Time spent  1.1368041038513184  sec
# realization  23  . Time spent  1.2724342346191406  sec
# realization  24  . Time spent  1.2540481090545654  sec
# realization  25  . Time spent  1.2477426528930664  sec
# realization  26  . Time spent  1.2592132091522217  sec
# realization  27  . Time spent  1.0643999576568604  sec
# realization  28  . Time spent  1.1987853050231934  sec
# realization  29  . Time spent  1.2570393085479736  sec
# realization  30  . Time spent  1.2589988708496094  sec
# realization  31  . Time spent  1.1840269565582275  sec
# realization  32  . Time spent  1.11287260055542  sec
# realization  33  . Time spent  1.4175238609313965  sec
# realization  34  . Time spent  1.075162649154663  sec
# realization  35  . Time spent  1.107771635055542  sec
# realization  36  . Time spent  1.1358566284179688  sec
# realization  37  . Time spent  1.1523001194000244  sec
# realization  38  . Time spent  1.2056267261505127  sec
# realization  39  . Time spent  1.2463369369506836  sec
# realization  40  . Time spent  1.3032751083374023  sec
# realization  41  . Time spent  1.0520715713500977  sec
# realization  42  . Time spent  1.1826231479644775  sec
# realization  43  . Time spent  1.1052517890930176  sec
# realization  44  . Time spent  1.0796470642089844  sec
# realization  45  . Time spent  1.1278715133666992  sec
# realization  46  . Time spent  1.217226266860962  sec
# realization  47  . Time spent  1.1155824661254883  sec
# realization  48  . Time spent  1.1004819869995117  sec
# realization  49  . Time spent  2.4641830921173096  sec
# realization  50  . Time spent  1.9197862148284912  sec
# realization  51  . Time spent  1.3988380432128906  sec
# realization  52  . Time spent  1.406446933746338  sec
# realization  53  . Time spent  1.0799944400787354  sec
# realization  54  . Time spent  1.0789227485656738  sec
# realization  55  . Time spent  1.2349061965942383  sec
# realization  56  . Time spent  1.0935842990875244  sec
# realization  57  . Time spent  1.2185907363891602  sec
# realization  58  . Time spent  1.240844964981079  sec
# realization  59  . Time spent  1.3897678852081299  sec
# realization  60  . Time spent  1.1697368621826172  sec
# realization  61  . Time spent  1.089707374572754  sec
# realization  62  . Time spent  1.060495376586914  sec
# realization  63  . Time spent  1.133350133895874  sec
# realization  64  . Time spent  1.0237095355987549  sec
# realization  65  . Time spent  1.0434396266937256  sec
# realization  66  . Time spent  1.1042869091033936  sec
# realization  67  . Time spent  1.164872407913208  sec
# realization  68  . Time spent  1.0748605728149414  sec
# realization  69  . Time spent  1.1050374507904053  sec
# realization  70  . Time spent  1.0252115726470947  sec
# realization  71  . Time spent  1.1147034168243408  sec
# realization  72  . Time spent  1.1599931716918945  sec
# realization  73  . Time spent  1.04646635055542  sec
# realization  74  . Time spent  1.352229356765747  sec
# realization  75  . Time spent  1.0634708404541016  sec
# realization  76  . Time spent  1.220301628112793  sec
# realization  77  . Time spent  1.0633621215820312  sec
# realization  78  . Time spent  1.065950870513916  sec
# realization  79  . Time spent  1.0460906028747559  sec
# realization  80  . Time spent  1.0276157855987549  sec
# realization  81  . Time spent  1.1985797882080078  sec
# realization  82  . Time spent  1.340106725692749  sec
# realization  83  . Time spent  1.2434430122375488  sec
# realization  84  . Time spent  1.1442735195159912  sec
# realization  85  . Time spent  1.3345098495483398  sec
# realization  86  . Time spent  1.0377144813537598  sec
# realization  87  . Time spent  1.0646934509277344  sec
# realization  88  . Time spent  1.8823208808898926  sec
# realization  89  . Time spent  1.0322120189666748  sec
# realization  90  . Time spent  1.1703400611877441  sec
# realization  91  . Time spent  1.3087806701660156  sec
# realization  92  . Time spent  1.1068787574768066  sec
# realization  93  . Time spent  1.0714480876922607  sec
# realization  94  . Time spent  1.0505945682525635  sec
# realization  95  . Time spent  1.0440635681152344  sec
# realization  96  . Time spent  1.0850963592529297  sec
# realization  97  . Time spent  1.0844943523406982  sec
# realization  98  . Time spent  1.6983520984649658  sec
# realization  99  . Time spent  1.068863868713379  sec
# realization  100  . Time spent  1.178379774093628  sec
# Total time spent  121.69716572761536  sec

# %%
fig, axes = plt.subplots(1,1,figsize = (5,3.5),dpi = 200)
N1_average, M1_average = data.T
N1_log = np.log(N1_average)
minus_delta1_log = N1_log - np.log(M1_average)
slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
print("estimated df(alpha, p)= ", slope)
plt.plot(minus_delta1_log, N1_log, "o")
plt.xlabel(r"$-\ln\,\delta$")
plt.ylabel(r"$\ln\,N$")
axes.set_position([0.15,0.15,0.75,0.75])
# Out:
# estimated df(alpha, p)=  0.7694358729785427

# %%
print("estimated   df = ", slope)
ana_soln = AnalyticSoln()
print("Theoritical df =", ana_soln.find_df(alphap, probp))
# Out:
# estimated   df =  0.7694358729785427
# Theoritical df = 0.778719

# %%
N1_average
# Out:
# array([31.9598 , 35.4946 , 38.23854, 40.52148, 42.47222, 44.20342,
#        45.76176, 47.17764, 48.48832, 49.69792, 50.83578, 51.89982,
#        52.90884, 53.86386, 54.77706, 55.64022, 56.47826, 57.27872,
#        58.04382])

# %%
M1_average
# Out:
# array([0.38694311, 0.37548351, 0.36760552, 0.36158594, 0.35677396,
#        0.35271343, 0.34921747, 0.34618691, 0.34349974, 0.34112199,
#        0.33891598, 0.33691986, 0.33505211, 0.33335506, 0.33179235,
#        0.33031889, 0.32892815, 0.32764366, 0.32641534])
