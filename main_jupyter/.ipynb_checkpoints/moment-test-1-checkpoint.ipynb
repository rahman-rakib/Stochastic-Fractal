# %%
# %run ../stochastic_fractal_m.py

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

dir_data = "../data/"
dir_fig = "../figures/"
os.listdir(dir_data)
# Out:
# ['README.txt']

# %%
## Getting the true lengths and plotting kde plot
# help(TrueLengths)

# %% [markdown]
# ## Moment $M_{d_f}$

# %%
df = 0.77872 # for alpha = 2 or beta = 1
sffl = FractalLength(alpha=2, probability=0.75, fractal_dim=df)
# Out:
# kwargs  {'alpha': 2, 'probability': 0.75, 'fractal_dim': 0.77872}

# %%
sffl.run(10000, 1000, 500, True)
# Out:
# [1.17447657 1.1803715  1.19558425 1.17896445 1.17850272 1.18798605
#  1.1910917  1.20222823 1.20222823 1.19626768 1.19626768 1.19626768
#  1.19110414 1.20099897 1.20099897 1.20099897 1.19778782 1.20751967]

# %%
sffl.run_ensemble(100, 10000, 1000, 500)
# Out:
# 1.055311705003669
# 1.055311705003669

# %%
sffl.run_ensemble(100, 20000, 1000, 500)
# Out:
# 0.9249396260073175
# 0.9249396260073175

# %%
sffl.run_ensemble(100, 30000, 1000, 500)
# Out:
# 1.0671352773043141
# 1.0671352773043141

# %% [markdown]
# ## Moment $M_{d_f - \Delta - 1}$

# %%
df = 0.77872 # for alpha = 2 or beta = 1
beta = 1
Delta = 2*beta
exponent = df - Delta - 1
print(exponent)
sffl = FractalLength(alpha=2, probability=0.75, exponent=exponent)
# Out:
# -2.22128
# kwargs  {'alpha': 2, 'probability': 0.75, 'exponent': -2.22128}

# %%
sffl.reset()
y = sffl.run(10000, 1000, 500, True)

# %%
x = np.arange(1000, 10000, 500)

# %%
plt.plot(x, y)

# %%
y = sffl.run_ensemble(50000, 10000, 1000, 500, True)
# Out:
# [9.40276244e+07 1.39311003e+08 1.88159660e+08 2.12821355e+08
#  2.36665481e+08 2.64337564e+08 3.69750459e+08 3.98717502e+08
#  4.22831205e+08 4.67249947e+08 5.12383052e+08 5.41029083e+08
#  5.73825789e+08 6.06698407e+08 6.45221735e+08 7.01058445e+08
#  7.44063123e+08 7.74319620e+08]

# %%
y
# Out:
# array([9.40276244e+07, 1.39311003e+08, 1.88159660e+08, 2.12821355e+08,
#        2.36665481e+08, 2.64337564e+08, 3.69750459e+08, 3.98717502e+08,
#        4.22831205e+08, 4.67249947e+08, 5.12383052e+08, 5.41029083e+08,
#        5.73825789e+08, 6.06698407e+08, 6.45221735e+08, 7.01058445e+08,
#        7.44063123e+08, 7.74319620e+08])

# %%
x = np.arange(1000, 10000, 500)

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 7), dpi=200)
plt.plot(x, y)
plt.ylabel(r"$M_{d_f - 2\beta-1}$")
plt.xlabel(r"$t$")
filename = "moment_df_minus_Delta_minus_1"
plt.savefig(dir_fig + filename)

# %%
import scipy.stats as stats

# %%
stats.linregress(x, y)
# Out:
# LinregressResult(slope=80080.19922277013, intercept=18049568.245232046, rvalue=0.997523605100316, pvalue=7.055862877621871e-20, stderr=1411.5552531432224)
