# %%
# %run ../stochastic_fractal_m.py

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

dir_data = "../data/"
os.listdir(dir_data)
# Out:
# ['StochasticFragmentation_Lengths__time-iteration_200000_ensemble_10000_20200918_012326.txt',
#  'StochasticFragmentation_Lengths__time-iteration_200000_ensemble_10000_20200918_012359.txt',
#  'README.txt',
#  'number_length',
#  'StochasticFragmentation_Lengths__time-iteration_200000_ensemble_10000_20200917_235809.txt',
#  'StochasticFragmentation_Lengths__time-iteration_200000_ensemble_10000_20200918_003943.txt',
#  'StochasticFragmentation_Lengths__time-iteration_100000_ensemble_10000_20200917_231826.txt']

# %%
## Getting the true lengths and plotting kde plot
# help(TrueLengths)

# %%
sfl = TrueLengths(alpha=2, probability=0.5)
# Out:
# kwargs  {'alpha': 2, 'probability': 0.5}
# Turning on logging

# %%
# sfl.run(10)

# %%
sfl.view()
# Out:
# viewing status
# alpha =  2
# keeping probability  0.5
# <length>  <probability>  <flag>
# 1.00000e+00, 1.00000e+00,     1
# 1.0
# 1.0

# %%
sfl.get_signature()
print(sfl.run_ensemble)
# Out:
# <bound method TrueLengths.run_ensemble of <main_py.stochastic_fragmentation.TrueLengths object at 0x7f84a7dc0dd0>>

# %%
a  = sfl.run_ensemble(10_000, 200_000)
# Out:
# realization  0  . Time spent  -3.814697265625e-06  sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-47987ff83b5d> in <module>
# ----> 1 a  = sfl.run_ensemble(10_000, 200_000)
#
# /run/media/shahnoor/drive01/Projects/Stochastic-Fractal/main_py/stochastic_fragmentation.py in run_ensemble(self, ensemble_size, time_iteration)
#     471                 pass
#     472             self.reset()
# --> 473             length = self.run(time_iteration)
#     474             self.lengths_ensemble = np.append(self.lengths_ensemble, length)
#     475             pass
#
# /run/media/shahnoor/drive01/Projects/Stochastic-Fractal/main_py/stochastic_fragmentation.py in run(self, time_iteration)
#     446         self.time_iteration = time_iteration
#     447         for i in range(time_iteration + 1):
# --> 448             self.one_time_step()
#     449             pass
#     450
#
# /run/media/shahnoor/drive01/Projects/Stochastic-Fractal/main_py/stochastic_fragmentation.py in one_time_step(self)
#     182     def one_time_step(self):
#     183         # print("StochasticFragmentation.one_time_step")
# --> 184         index = self.pickindex()
#     185         # print("index ", index)
#     186         if (type(index) == int) and self.flag_list[index]:
#
# /run/media/shahnoor/drive01/Projects/Stochastic-Fractal/main_py/stochastic_fragmentation.py in pickindex(self)
#     122         """
#     123         # return self.pickindex_v1()
# --> 124         return self.pickindex_v2()
#     125
#     126
#
# /run/media/shahnoor/drive01/Projects/Stochastic-Fractal/main_py/stochastic_fragmentation.py in pickindex_v2(self)
#     149         # print("pickindex_v2")
#     150         # print("self.probability_list ", self.probability_list)
# --> 151         r = random.uniform(0, 1.0)  # 1 is the initial particle size
#     152         if r > self.normC:
#     153             # print("r > self.normC => return None")
#
# ~/software/anaconda3/lib/python3.7/random.py in uniform(self, a, b)
#     372     def uniform(self, a, b):
#     373         "Get a random number in the range [a, b) or [a, b] depending on rounding."
# --> 374         return a + (b-a) * self.random()
#     375
#     376 ## -------------------- triangular --------------------
#
# KeyboardInterrupt:

# %%
sns.distplot(a)

# %%
sns.distplot(a*100_000**(1/3))

# %%
sns.kdeplot(a*10000**(1/3))

# %%
sfl.save_to_file(dir_data, "true lengths")

# %%
sfl.get_filename()
# Out:
# 'StochasticFragmentation_Lengths__time-iteration_200000_ensemble_10000_20200918_012402.txt'

# %%
filename = dir_data+"StochasticFragmentation_Lengths__time-iteration_1000_ensemble_100_20200901_090221.txt"
data = np.loadtxt(filename)
sns.kdeplot(data)
