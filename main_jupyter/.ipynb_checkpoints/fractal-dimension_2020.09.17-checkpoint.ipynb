# %%
# %run ../stochastic_fractal_m.py

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import json
import numpy as np

dir_data = "../data/number_length/p=0.25,alpha=2/"
os.listdir(dir_data)
# Out:
# ['StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200919_210411.txt',
#  'StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200920_051248.txt',
#  'StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200919_165241.txt',
#  'StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200920_151121.txt']

# %%
## Getting the true lengths and plotting kde plot
# help(TrueLengths)

# %% [markdown]
# # Fractal dimensions
#
# Ensemble size = 50,000
#
# Max Time iteration = 1,000,000
#
# initial time to record data = 100,000
#
# number of data points = 20
#
#
#
# | $alpha$  |    $p$   | actual $d_f$ | simulation $d_f$ |
# |----------|:--------:|------:|------:|
# | 2 |  0.75 | 1600 |
# | 3 |  0.75 | 12  |
# | 2 |  0.50 |    0.541381 | 0.539152
# | 3 |  0.50 |    0.555779 | 0.597432
# | 2 |  0.25 |    0.283882 | 0.282004
# | 3 |  0.25 |    0.296196 | 0.295501

# %% [markdown]
# ## Number length

# %%
sfl = NumberLength(alpha=2, probability=0.25)
sfl.log(True)
# Out:
# kwargs  {'alpha': 2, 'probability': 0.25}

# %%
sfl.run(10000, 5000, 10)
# Out:
# array([[3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577],
#        [3.        , 0.08142577]])

# %%
data = sfl.run_ensemble(10_000, 1_000_000, 100_000, 50)
# Out:
# realization  0  . Time spent  8.344650268554688e-06  sec
# realization  100  . Time spent  177.43201518058777  sec
# realization  200  . Time spent  162.6637511253357  sec
# realization  300  . Time spent  151.4317798614502  sec
# realization  400  . Time spent  157.51749205589294  sec
# realization  500  . Time spent  146.1482207775116  sec
# realization  600  . Time spent  172.4371519088745  sec
# realization  700  . Time spent  174.12798714637756  sec
# realization  800  . Time spent  159.57828545570374  sec
# realization  900  . Time spent  155.22762298583984  sec
# realization  1000  . Time spent  153.5796504020691  sec
# realization  1100  . Time spent  175.82083582878113  sec
# realization  1200  . Time spent  169.22662591934204  sec
# realization  1300  . Time spent  199.26670241355896  sec
# realization  1400  . Time spent  193.3172242641449  sec
# realization  1500  . Time spent  179.82528233528137  sec
# realization  1600  . Time spent  153.34966373443604  sec
# realization  1700  . Time spent  154.0038402080536  sec
# realization  1800  . Time spent  159.5166244506836  sec
# realization  1900  . Time spent  153.84162378311157  sec
# realization  2000  . Time spent  151.00631642341614  sec
# realization  2100  . Time spent  150.58384370803833  sec
# realization  2200  . Time spent  150.63846921920776  sec
# realization  2300  . Time spent  149.3136076927185  sec
# realization  2400  . Time spent  160.30376887321472  sec
# realization  2500  . Time spent  179.36447262763977  sec
# realization  2600  . Time spent  167.5903811454773  sec
# realization  2700  . Time spent  158.0922417640686  sec
# realization  2800  . Time spent  154.17340731620789  sec
# realization  2900  . Time spent  162.0751383304596  sec
# realization  3000  . Time spent  160.44029688835144  sec
# realization  3100  . Time spent  179.68514823913574  sec
# realization  3200  . Time spent  185.96151208877563  sec
# realization  3300  . Time spent  155.3741683959961  sec
# realization  3400  . Time spent  143.1223886013031  sec
# realization  3500  . Time spent  143.14709544181824  sec
# realization  3600  . Time spent  149.881041765213  sec
# realization  3700  . Time spent  153.92767024040222  sec
# realization  3800  . Time spent  145.1585373878479  sec
# realization  3900  . Time spent  150.67522978782654  sec
# realization  4000  . Time spent  144.90240788459778  sec
# realization  4100  . Time spent  146.12573075294495  sec
# realization  4200  . Time spent  192.6434555053711  sec
# realization  4300  . Time spent  186.74176859855652  sec
# realization  4400  . Time spent  168.70827221870422  sec
# realization  4500  . Time spent  169.14531421661377  sec
# realization  4600  . Time spent  199.2646346092224  sec
# realization  4700  . Time spent  197.99983930587769  sec
# realization  4800  . Time spent  213.99918413162231  sec
# realization  4900  . Time spent  182.40796637535095  sec
# realization  5000  . Time spent  158.9744532108307  sec
# realization  5100  . Time spent  169.59271812438965  sec
# realization  5200  . Time spent  160.71849632263184  sec
# realization  5300  . Time spent  164.27576327323914  sec
# realization  5400  . Time spent  173.5699167251587  sec
# realization  5500  . Time spent  167.70746994018555  sec
# realization  5600  . Time spent  166.7800371646881  sec
# realization  5700  . Time spent  149.790531873703  sec
# realization  5800  . Time spent  147.99966144561768  sec
# realization  5900  . Time spent  149.38747596740723  sec
# realization  6000  . Time spent  147.50808954238892  sec
# realization  6100  . Time spent  160.62457299232483  sec
# realization  6200  . Time spent  154.14432573318481  sec
# realization  6300  . Time spent  149.71252632141113  sec
# realization  6400  . Time spent  152.38058280944824  sec
# realization  6500  . Time spent  153.2711923122406  sec
# realization  6600  . Time spent  151.66357350349426  sec
# realization  6700  . Time spent  152.08301401138306  sec
# realization  6800  . Time spent  168.73956561088562  sec
# realization  6900  . Time spent  166.01180481910706  sec
# realization  7000  . Time spent  167.04799842834473  sec
# realization  7100  . Time spent  150.93327069282532  sec
# realization  7200  . Time spent  149.72760701179504  sec
# realization  7300  . Time spent  155.31980443000793  sec
# realization  7400  . Time spent  159.96897530555725  sec
# realization  7500  . Time spent  157.391019821167  sec
# realization  7600  . Time spent  177.3814468383789  sec
# realization  7700  . Time spent  179.89034247398376  sec
# realization  7800  . Time spent  174.56903386116028  sec
# realization  7900  . Time spent  158.58611583709717  sec
# realization  8000  . Time spent  148.3326473236084  sec
# realization  8100  . Time spent  144.567791223526  sec
# realization  8200  . Time spent  144.03062868118286  sec
# realization  8300  . Time spent  148.12981390953064  sec
# realization  8400  . Time spent  149.24139976501465  sec
# realization  8500  . Time spent  144.92994379997253  sec
# realization  8600  . Time spent  145.5954098701477  sec
# realization  8700  . Time spent  144.36228370666504  sec
# realization  8800  . Time spent  142.33314514160156  sec
# realization  8900  . Time spent  141.95659565925598  sec
# realization  9000  . Time spent  141.56601643562317  sec
# realization  9100  . Time spent  146.21042346954346  sec
# realization  9200  . Time spent  144.91826701164246  sec
# realization  9300  . Time spent  143.15426468849182  sec
# realization  9400  . Time spent  147.98493909835815  sec
# realization  9500  . Time spent  147.72776556015015  sec
# realization  9600  . Time spent  147.77273297309875  sec
# realization  9700  . Time spent  142.24262714385986  sec
# realization  9800  . Time spent  165.75366115570068  sec
# realization  9900  . Time spent  203.10076570510864  sec

# %%
filename = dir_data + sfl.get_filename()
header_js = sfl.get_header(
    {"columns":['number of particles', 'sum of surviving particle sizes'],
     "type":"ensemble average"     
    }
)
np.savetxt(filename, data, header=json.dumps(header_js))

tmp = np.loadtxt(filename)
plt.plot(tmp[:,0], tmp[:,1], 'o')

# %%
sfl = NumberLength(alpha=2, probability=0.25)
sfl.log(True)

data = sfl.run_ensemble(10_000, 1_000_000, 100_000, 50)

# %%
filename = dir_data + sfl.get_filename()
header_js = sfl.get_header(
    {"columns":['number of particles', 'sum of surviving particle sizes'],
     "type":"ensemble average"     
    }
)
np.savetxt(filename, data, header=json.dumps(header_js))

tmp = np.loadtxt(filename)
plt.plot(tmp[:,0], tmp[:,1], 'o')

# %%
N1_average, M1_average = data.T

# %%
def convert_to_plot(N1_average, M1_average):
    N1_log = np.log(N1_average)
    minus_delta1_log = N1_log - np.log(M1_average)
    slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
    return minus_delta1_log, N1_log, slope, intercept

# %%
minus_delta1_log, N1_log, slope, intercept = convert_to_plot(N1_average, M1_average)
print("fractal dimension, df =", slope)
plt.plot(minus_delta1_log, N1_log, "o")
plt.xlabel(r"$-\ln\,\delta$")
plt.ylabel(r"$\ln\,N$")
# Out:
# fractal dimension, df = 0.281265398517281
# Text(0, 0.5, '$\\ln\\,N$')

# %% [markdown]
# ## Analysis

# %%
dir_data = "../data/number_length/p=0.25,alpha=2/"
dir_figure = "../figures/fractal-dimension/"
print(os.listdir(dir_data))
signature = "fractal_dimension_alpha_2_p_0_25"
# Out:
# ['StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200919_210411.txt', 'StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200920_051248.txt', 'StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200919_165241.txt', 'StochasticFragmentationNumberLength_time-iteration_1000000_ensemble_10000_20200920_151121.txt']

# %%
def convert_to_plot(N1_average, M1_average):
    N1_log = np.log(N1_average)
    minus_delta1_log = N1_log - np.log(M1_average)
    slope, intercept = np.polyfit(minus_delta1_log, N1_log, 1)
    return minus_delta1_log, N1_log, slope, intercept

# %%
files = glob.glob(dir_data + "*")
for file in files:
    with open(file) as f:
        line = f.readline()
        header = json.loads(line[1:])
        time_iteration = header['time_iteration']
        ensemble_size = header['ensemble_size']
        alpha = header['alpha']
        probability = header['probability']
        print(header)
    data = np.loadtxt(file)
    N1_average, M1_average = data.T
    print(N1_average)
    minus_delta1_log, N1_log, slope, intercept = convert_to_plot(N1_average, M1_average)
    plt.plot(minus_delta1_log, N1_log, 'o', label="T={}".format(time_iteration))
    pass
plt.legend()
# Out:
# {'time_iteration': 1000000, 'date_time': '20200919_210411', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# [3.6087 3.6621 3.709  3.7508 3.7915 3.825  3.8576 3.8876 3.9126 3.939
#  3.9627 3.9835 4.0042 4.024  4.0431 4.0583 4.0768 4.0934 4.1074 4.1232
#  4.1404 4.1543 4.1679 4.1813 4.1956 4.2087 4.2214 4.2335 4.2457 4.2559
#  4.2666 4.2767 4.2871 4.2976 4.3095 4.3192 4.3304 4.3395 4.3493 4.3604
#  4.3716 4.3803 4.3895 4.3988 4.4069 4.4162 4.4246 4.4311 4.4403 4.4472]
# {'time_iteration': 1000000, 'date_time': '20200920_051248', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# [3.5788 3.6322 3.6774 3.7152 3.7534 3.7875 3.8178 3.8488 3.8757 3.9005
#  3.9227 3.9467 3.9678 3.9889 4.0089 4.027  4.0442 4.0599 4.0751 4.0917
#  4.1048 4.1189 4.1314 4.1444 4.1591 4.1732 4.1864 4.199  4.2115 4.224
#  4.2332 4.2452 4.2554 4.2654 4.274  4.2845 4.294  4.3028 4.3127 4.3218
#  4.3299 4.339  4.3482 4.3579 4.3644 4.3734 4.382  4.3891 4.3971 4.405 ]
# {'time_iteration': 1000000, 'date_time': '20200919_165241', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# [3.6108 3.6593 3.7075 3.7488 3.7878 3.8233 3.8544 3.8859 3.9121 3.9375
#  3.9593 3.9816 4.0051 4.024  4.0437 4.0626 4.079  4.0948 4.1127 4.129
#  4.1454 4.1585 4.1722 4.1873 4.1999 4.2119 4.2222 4.2347 4.2452 4.2575
#  4.2691 4.2793 4.2888 4.2993 4.3094 4.3205 4.3298 4.3388 4.3475 4.3549
#  4.3647 4.3732 4.3829 4.3904 4.3987 4.4064 4.413  4.4221 4.4297 4.4379]
# {'time_iteration': 1000000, 'date_time': '20200920_151121', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# [3.5737 3.6256 3.6662 3.7077 3.7427 3.7786 3.8129 3.842  3.8691 3.8949
#  3.9159 3.938  3.9601 3.9809 4.0006 4.0195 4.0346 4.0515 4.07   4.0875
#  4.1049 4.1188 4.1314 4.1461 4.1596 4.1709 4.1835 4.1959 4.2086 4.2228
#  4.2346 4.2472 4.2574 4.2673 4.2787 4.2892 4.2983 4.3067 4.3184 4.3287
#  4.3382 4.3478 4.3565 4.3651 4.3729 4.3801 4.3877 4.396  4.4027 4.4102]

# %%
def get_mean_data(files):
    data_sum = None
    ensemble_size = 0
    for file in files:
        with open(file) as f:
            line = f.readline()
            header = json.loads(line[1:])
            time_iteration = header['time_iteration']
            En = header['ensemble_size']
            alpha = header['alpha']
            probability = header['probability']
            print(header)
            pass
        data = np.loadtxt(file)
        N1_average, M1_average = data.T
        minus_delta1_log, N1_log, slope, intercept = convert_to_plot(N1_average, M1_average)
        print("slope ", slope)
        if data_sum is None:
            data_sum = data*En
            pass
        else:
            data_sum += data*En
        ensemble_size += En
        pass
    return data_sum / ensemble_size

# %%
    
files = glob.glob(dir_data + "*")
data = get_mean_data(files)

N1_average, M1_average = data.T
print(N1_average)
minus_delta1_log, N1_log, slope, intercept = convert_to_plot(N1_average, M1_average)

fig, ax = plt.subplots(1, 1, figsize=(5, 3.5), dpi=300)
plt.plot(minus_delta1_log, N1_log, 'o', label="T={}k".format(time_iteration//1000), markersize=2)

y = minus_delta1_log*slope + intercept
plt.plot(minus_delta1_log, y, label="fitted", lw=1)
plt.xlabel(r"$\log (N/M)$")
plt.ylabel(r"$\log N$")
plt.legend()
ax.set_position([0.15, 0.15, 0.8, 0.8])
fig.text(0.1, 0.6, r'$\alpha={}, p={}$'.format(alpha,probability), transform=ax.transAxes)
fig.text(0.1, 0.5, r'$d_f={:.6f}$'.format(slope), transform=ax.transAxes)

filename = dir_figure + signature + ".pdf"
plt.savefig(filename)
# Out:
# {'time_iteration': 1000000, 'date_time': '20200919_210411', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# slope  0.281265398517281
# {'time_iteration': 1000000, 'date_time': '20200920_051248', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# slope  0.28237963983840825
# {'time_iteration': 1000000, 'date_time': '20200919_165241', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# slope  0.27866889206177675
# {'time_iteration': 1000000, 'date_time': '20200920_151121', 'ensemble_size': 10000, 'alpha': 2, 'probability': 0.25, 'desc': {'columns': ['number of particles', 'sum of surviving particle sizes'], 'type': 'ensemble average'}}
# slope  0.28572328184939144
# [3.593    3.6448   3.690025 3.730625 3.76885  3.8036   3.835675 3.866075
#  3.892375 3.917975 3.94015  3.96245  3.9843   4.00445  4.024075 4.04185
#  4.05865  4.0749   4.0913   4.10785  4.123875 4.137625 4.150725 4.164775
#  4.17855  4.191175 4.203375 4.215775 4.22775  4.24005  4.250875 4.2621
#  4.272175 4.2824   4.2929   4.30335  4.313125 4.32195  4.331975 4.34145
#  4.3511   4.360075 4.369275 4.37805  4.385725 4.394025 4.401825 4.409575
#  4.41745  4.425075]
